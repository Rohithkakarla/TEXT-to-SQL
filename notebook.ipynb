# %%
# !git clone https://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@github.com/Rohithkakarla/TEXT-to-SQL.git

# %%
# !pip3 install -r /kaggle/working/TEXT-to-SQL/requirements.txt

# %%
# !gdown --id 13Abvu5SUMSP3SJM-ZIj66mOkeyAquR73

# %%
# !unzip /kaggle/working/sparc.zip -d /kaggle/working/TEXT-to-SQL/data/sparc

# %%
# !gdown --id 1f_LEWVgrtZLRuoiExJa5fNzTS8-WcAX9

# %%
# !cp pytorch_model_uncased_L-12_H-768_A-12.bin ./TEXT-to-SQL/model/bert/data/annotated_wikisql_and_PyTorch_bert_param/

# %%
# %cd TEXT-to-SQL/

# %%
# !pip3 install nltk

# %%
import nltk
nltk.download('punkt')

# %%
# !pip3 install kaggle

# %%
# !mkdir ~/.kaggle

# %%
with open('/kaggle/working/kaggle.json', 'w') as writefile:
    writefile.write('{"username":"rohithkakarla","key":"c2aefd62b733590d770bd9d2f7bacf29"}')

# %%
# !cp /kaggle/working/kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !gdown --id 1a828mkHcgyQCBgVla0jGxKJ58aV8RsYK

# %%
# !unzip database.zip -d data/

# %%
# !kaggle datasets download takuok/glove840b300dtxt

# %%
# !unzip glove840b300dtxt.zip -d /kaggle/working

# %%
# !bash run_sparc.sh

# %%
# !gdown --id 1MRN3_mklw8biUphFxmD7OXJ57yS-FkJP

# %%
# !cp save_31_sparc_editsql -d logs/logs_sparc_editsql/

# %%
# !bash test_sparc.sh

# %%
import json
out=[]
with open('logs/logs_sparc_editsql/valid_use_predicted_queries_predictions.json') as f:
  for entry in f:
    data = json.loads(entry)
    out.append(data)

with open('readable.txt', 'w') as json_file:
  for item in out:
    json.dump(item['input_seq'], json_file)
    json_file.write('\n')
    json.dump(item['prediction'], json_file)
    json_file.write('\n')

# %%
# !cat readable.txt
